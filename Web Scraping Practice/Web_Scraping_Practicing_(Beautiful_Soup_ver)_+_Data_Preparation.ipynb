# %% [markdown]
# # Beautiful Soup 🍲

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
# URL of Webpage to Scrape
url = 'https://www.wineenthusiast.com/toplists/enthusiast-100-2023/' # Top 100 Wines

#Send a GET request
response = requests.get(url)

#Check if the request was successful
if response.status_code == 200:

    #Parse the HTML Content
    soup = BeautifulSoup(response.content, 'html.parser')

    #Find all the wine cards
    wine_entries = soup.find_all('div', class_='card-container')

    #Empty Wine Data Container
    wine_data = []
    for entry in wine_entries:
      rank = entry.find('h3', class_='review-ranking').text.strip()
      name = entry.find('p', class_='review-item').text.strip()
      wine_type = entry.find('div', class_='wine-type').text.strip()
      country= entry.find('p', class_='review-location').text.strip()
      points = entry.find('span', class_='points').text.strip()
      price = entry.find('span', class_='price').text.strip()

      # Create Wine Data
      wine_data.append({'Rank': rank,
                        'Name': name,
                        "Type": wine_type,
                        "Location": country,
                        "Points": points,
                        "Price": price
                        })

else:
  print('Requests Denied: ', response.status_code)

# Convert into Dataframe
ratings = pd.DataFrame(wine_data).sort_values(by = 'Rank', ascending=True)

# Optional Save
# ratings.to_csv("Wine Ratings.csv", index=False)
ratings
# Out:
#      Rank                                               Name  \
# 99    #1.  Duckhorn 2019 Monitor Ledge Vineyard Cabernet ...
# 90   #10.               Cayuse 2020 En Cerise Vineyard Syrah
# 0   #100.     Sipwell 2021 Tiny Victories Sparkling Albariño
# 89   #11.  Louis M. Martini 2019 Lot No. 1 Cabernet Sauvi...
# 88   #12.     Anne-Sophie Pic & Michel Chapoutier 2021 Syrah
# ..    ...                                                ...
# 5    #95.                         Manzanos 2021 111 Graciano
# 4    #96.       Morandé 2019 Morandé Adventure Tirazis Syrah
# 3    #97.                   Mary Taylor 2019 Marine Descombe
# 2    #98.          Raats Family 2019 Dolomite Cabernet Franc
# 1    #99.  Pietro Beconcini 2021 Fresco di Nero, Rosé of ...
#
#                   Type                                           Location  \
# 99  Cabernet Sauvignon  Red Wine from\n                               ...
# 90               Syrah  Red Wine from\n                               ...
# 0             Albariño  Sparkling Wine from\n                         ...
# 89  Cabernet Sauvignon  Red Wine from\n                               ...
# 88               Syrah  Red Wine from\n                               ...
# ..                 ...                                                ...
# 5          Spanish Red  Red Wine from\n                               ...
# 4                Syrah  Red Wine from\n                               ...
# 3                Gamay  Red Wine from\n                               ...
# 2       Cabernet Franc  Red Wine from\n                               ...
# 1                 Rosé  Rosé Wine from\n                              ...
#
#     Points Price
# 99  96 pts  $105
# 90  96 pts   $94
# 0   90 pts    $6
# 89  96 pts  $250
# 88  95 pts   N/A
# ..     ...   ...
# 5   91 pts   $24
# 4   91 pts   $32
# 3   91 pts   $32
# 2   90 pts   $21
# 1   90 pts   $25
#
# [100 rows x 6 columns]

# %% [markdown]
# ### **Initial Insights**
# Scraped website is from the Wine Enthusiest showing the top 100 wines.
# Link : https://www.wineenthusiast.com/toplists/enthusiast-100-2023/
#
# Data Scraped from the website is succesful. Further cleaning will be needed to correct data types. With null values under price, I can confirm that there is no data for those.

# %% [markdown]
# ## Data Preprocessing

# %%
# Duplicate df to avoid running the scraping multiple times
main_df = ratings.copy()

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 99 to 1
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rank      100 non-null    object
#  1   Name      100 non-null    object
#  2   Type      100 non-null    object
#  3   Location  100 non-null    object
#  4   Points    100 non-null    object
#  5   Price     100 non-null    object
# dtypes: object(6)
# memory usage: 5.5+ KB

# %%
main_df
# Out:
#      Rank                                                            Name  \
# 99    #1.         Duckhorn 2019 Monitor Ledge Vineyard Cabernet Sauvignon
# 90   #10.                            Cayuse 2020 En Cerise Vineyard Syrah
# 0   #100.                  Sipwell 2021 Tiny Victories Sparkling Albariño
# 89   #11.              Louis M. Martini 2019 Lot No. 1 Cabernet Sauvignon
# 88   #12.                  Anne-Sophie Pic & Michel Chapoutier 2021 Syrah
# ..    ...                                                             ...
# 5    #95.                                      Manzanos 2021 111 Graciano
# 4    #96.                    Morandé 2019 Morandé Adventure Tirazis Syrah
# 3    #97.                                Mary Taylor 2019 Marine Descombe
# 2    #98.                       Raats Family 2019 Dolomite Cabernet Franc
# 1    #99.  Pietro Beconcini 2021 Fresco di Nero, Rosé of Tempranillo Rosé
#
#                   Type  \
# 99  Cabernet Sauvignon
# 90               Syrah
# 0             Albariño
# 89  Cabernet Sauvignon
# 88               Syrah
# ..                 ...
# 5          Spanish Red
# 4                Syrah
# 3                Gamay
# 2       Cabernet Franc
# 1                 Rosé
#
#                                                                                                     Location  \
# 99                  Red Wine from\n                                            Napa Valley, Napa, California
# 90  Red Wine from\n                                            Walla Walla Valley (OR), Oregon Other, Oregon
# 0          Sparkling Wine from\n                                            Lodi, Central Valley, California
# 89                  Red Wine from\n                                            Napa Valley, Napa, California
# 88                   Red Wine from\n                                            Cornas, Rhône Valley, France
# ..                                                                                                       ...
# 5                    Red Wine from\n                                            Rioja, Northern Spain, Spain
# 4                        Red Wine from\n                                            Casablanca Valley, Chile
# 3                    Red Wine from\n                                            Juliénas, Beaujolais, France
# 2                      Red Wine from\n                                            Stellenbosch, South Africa
# 1                        Rosé Wine from\n                                            Toscana, Tuscany, Italy
#
#     Points Price
# 99  96 pts  $105
# 90  96 pts   $94
# 0   90 pts    $6
# 89  96 pts  $250
# 88  95 pts   N/A
# ..     ...   ...
# 5   91 pts   $24
# 4   91 pts   $32
# 3   91 pts   $32
# 2   90 pts   $21
# 1   90 pts   $25
#
# [100 rows x 6 columns]

# %%
main_df.columns = ['Rank', 'Name', 'Type', 'Location', 'Points', 'Price($)']

# %%
main_df['Rank'] = main_df['Rank'].str.extract(r'(\d+)').astype(int) # Extracts the Rank Number and Converts to Int Type
main_df.sort_values(by='Rank', ascending=True, inplace=True) # Sorts data by Rank

# %%
main_df
# Out:
#     Rank                                                            Name  \
# 99     1         Duckhorn 2019 Monitor Ledge Vineyard Cabernet Sauvignon
# 98     2                                 Ratti 2019 Serradenari Nebbiolo
# 97     3                        Schnaitmann 2019 Lämmler GG Dry Riesling
# 96     4                                  Brewer-Clifton 2021 Pinot Noir
# 95     5           Rippon 2019 Rippon Mature Vine Lake Wanaka Pinot Noir
# ..   ...                                                             ...
# 4     96                    Morandé 2019 Morandé Adventure Tirazis Syrah
# 3     97                                Mary Taylor 2019 Marine Descombe
# 2     98                       Raats Family 2019 Dolomite Cabernet Franc
# 1     99  Pietro Beconcini 2021 Fresco di Nero, Rosé of Tempranillo Rosé
# 0    100                  Sipwell 2021 Tiny Victories Sparkling Albariño
#
#                   Type  \
# 99  Cabernet Sauvignon
# 98            Nebbiolo
# 97            Riesling
# 96          Pinot Noir
# 95          Pinot Noir
# ..                 ...
# 4                Syrah
# 3                Gamay
# 2       Cabernet Franc
# 1                 Rosé
# 0             Albariño
#
#                                                                                                  Location  \
# 99               Red Wine from\n                                            Napa Valley, Napa, California
# 98                     Red Wine from\n                                            Barolo, Piedmont, Italy
# 97                      White Wine from\n                                            Württemberg, Germany
# 96  Red Wine from\n                                            Sta. Rita Hills, Central Coast, California
# 95                  Red Wine from\n                                            Central Otago, New Zealand
# ..                                                                                                    ...
# 4                     Red Wine from\n                                            Casablanca Valley, Chile
# 3                 Red Wine from\n                                            Juliénas, Beaujolais, France
# 2                   Red Wine from\n                                            Stellenbosch, South Africa
# 1                     Rosé Wine from\n                                            Toscana, Tuscany, Italy
# 0       Sparkling Wine from\n                                            Lodi, Central Valley, California
#
#     Points Price($)
# 99  96 pts     $105
# 98  97 pts     $175
# 97  97 pts      $75
# 96  95 pts      $45
# 95  97 pts      $65
# ..     ...      ...
# 4   91 pts      $32
# 3   91 pts      $32
# 2   90 pts      $21
# 1   90 pts      $25
# 0   90 pts       $6
#
# [100 rows x 6 columns]

# %%
main_df['Points'] = main_df['Points'].str.extract(r'(\d+)').astype(int)
main_df['Price($)'] = main_df['Price($)'].replace('N/A', '0')

# %%
main_df[main_df['Price($)'] == 'N/A'] # to check if data got replaced
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Type, Location, Points, Price($)]
# Index: []

# %%
main_df['Price($)'] = main_df['Price($)'].str.extract(r'(\d+)').astype(float)

# %%
pd.set_option("display.max_colwidth", 10000) # To see
main_df['Location'] = main_df['Location'].str.replace(r'/^\s+|\s+$|\s+(?=\s)/g', "")

# %%
main_df['WineType'] = main_df['Location'].str.extract(r'(\w+ Wine)')

# %%
main_df
# Out:
#     Rank                                                            Name  \
# 99     1         Duckhorn 2019 Monitor Ledge Vineyard Cabernet Sauvignon
# 98     2                                 Ratti 2019 Serradenari Nebbiolo
# 97     3                        Schnaitmann 2019 Lämmler GG Dry Riesling
# 96     4                                  Brewer-Clifton 2021 Pinot Noir
# 95     5           Rippon 2019 Rippon Mature Vine Lake Wanaka Pinot Noir
# ..   ...                                                             ...
# 4     96                    Morandé 2019 Morandé Adventure Tirazis Syrah
# 3     97                                Mary Taylor 2019 Marine Descombe
# 2     98                       Raats Family 2019 Dolomite Cabernet Franc
# 1     99  Pietro Beconcini 2021 Fresco di Nero, Rosé of Tempranillo Rosé
# 0    100                  Sipwell 2021 Tiny Victories Sparkling Albariño
#
#                   Type  \
# 99  Cabernet Sauvignon
# 98            Nebbiolo
# 97            Riesling
# 96          Pinot Noir
# 95          Pinot Noir
# ..                 ...
# 4                Syrah
# 3                Gamay
# 2       Cabernet Franc
# 1                 Rosé
# 0             Albariño
#
#                                                                                                  Location  \
# 99               Red Wine from\n                                            Napa Valley, Napa, California
# 98                     Red Wine from\n                                            Barolo, Piedmont, Italy
# 97                      White Wine from\n                                            Württemberg, Germany
# 96  Red Wine from\n                                            Sta. Rita Hills, Central Coast, California
# 95                  Red Wine from\n                                            Central Otago, New Zealand
# ..                                                                                                    ...
# 4                     Red Wine from\n                                            Casablanca Valley, Chile
# 3                 Red Wine from\n                                            Juliénas, Beaujolais, France
# 2                   Red Wine from\n                                            Stellenbosch, South Africa
# 1                     Rosé Wine from\n                                            Toscana, Tuscany, Italy
# 0       Sparkling Wine from\n                                            Lodi, Central Valley, California
#
#     Points  Price($)        WineType
# 99      96     105.0        Red Wine
# 98      97     175.0        Red Wine
# 97      97      75.0      White Wine
# 96      95      45.0        Red Wine
# 95      97      65.0        Red Wine
# ..     ...       ...             ...
# 4       91      32.0        Red Wine
# 3       91      32.0        Red Wine
# 2       90      21.0        Red Wine
# 1       90      25.0       Rosé Wine
# 0       90       6.0  Sparkling Wine
#
# [100 rows x 7 columns]

# %%
main_df['Location'] = main_df['Location'].str.extract('from\\n [ \t]*([^\n\r]*)')

# %%
main_df['Date'] = main_df['Name'].str.extract('(\d+)')
# Out:
# <ipython-input-262-195da789bf5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df['Date'] = main_df['Name'].str.extract('(\d+)')

# %%
main_df = main_df[['Rank', 'Date','Name','WineType', 'Type', 'Location', 'Points', 'Price($)']]

# %%
main_df
# Out:
#     Rank  Date  \
# 99     1  2019
# 98     2  2019
# 97     3  2019
# 96     4  2021
# 95     5  2019
# ..   ...   ...
# 4     96  2019
# 3     97  2019
# 2     98  2019
# 1     99  2021
# 0    100  2021
#
#                                                               Name  \
# 99         Duckhorn 2019 Monitor Ledge Vineyard Cabernet Sauvignon
# 98                                 Ratti 2019 Serradenari Nebbiolo
# 97                        Schnaitmann 2019 Lämmler GG Dry Riesling
# 96                                  Brewer-Clifton 2021 Pinot Noir
# 95           Rippon 2019 Rippon Mature Vine Lake Wanaka Pinot Noir
# ..                                                             ...
# 4                     Morandé 2019 Morandé Adventure Tirazis Syrah
# 3                                 Mary Taylor 2019 Marine Descombe
# 2                        Raats Family 2019 Dolomite Cabernet Franc
# 1   Pietro Beconcini 2021 Fresco di Nero, Rosé of Tempranillo Rosé
# 0                   Sipwell 2021 Tiny Victories Sparkling Albariño
#
#           WineType                Type  \
# 99        Red Wine  Cabernet Sauvignon
# 98        Red Wine            Nebbiolo
# 97      White Wine            Riesling
# 96        Red Wine          Pinot Noir
# 95        Red Wine          Pinot Noir
# ..             ...                 ...
# 4         Red Wine               Syrah
# 3         Red Wine               Gamay
# 2         Red Wine      Cabernet Franc
# 1        Rosé Wine                Rosé
# 0   Sparkling Wine            Albariño
#
#                                       Location  Points  Price($)
# 99               Napa Valley, Napa, California      96     105.0
# 98                     Barolo, Piedmont, Italy      97     175.0
# 97                        Württemberg, Germany      97      75.0
# 96  Sta. Rita Hills, Central Coast, California      95      45.0
# 95                  Central Otago, New Zealand      97      65.0
# ..                                         ...     ...       ...
# 4                     Casablanca Valley, Chile      91      32.0
# 3                 Juliénas, Beaujolais, France      91      32.0
# 2                   Stellenbosch, South Africa      90      21.0
# 1                      Toscana, Tuscany, Italy      90      25.0
# 0             Lodi, Central Valley, California      90       6.0
#
# [100 rows x 8 columns]
